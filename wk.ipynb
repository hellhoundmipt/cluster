# %%
f = open('D:/Max/docs_cluster/ruwiki-20171103-pages-meta-current.xml', 'r')
c = 
for i in range(50):
    print(f[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-eb85131c484b> in <module>()
#       1 f = open('D:/Max/docs_cluster/ruwiki-20171103-pages-meta-current.xml', 'r')
#       2 for i in range(50):
# ----> 3     print(f[i])
#       4
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
import pandas
df = pandas.read_csv("C:/Users/Maxim/Downloads/en_20090306/categorylink.csv")

# %%
import mediawiki

wikipedia = mediawiki.MediaWiki(lang=u'ru')
p = wikipedia.page("Россия")
s = wikipedia.page("Стас Барецкий")
print(p.categories)
print('')
print(p.links)
print('')
print('')
print('')
print(s.title)
print(s.categories)
print('')
print(s.links)
# Out:
# ['Категория:Аудиостатьи', 'Категория:Баренц-регион', 'Категория:Государства «Большой двадцатки»', 'Категория:Государства по алфавиту', 'Категория:Государства постсоветского пространства', 'Категория:Россия', 'Категория:Страны и регионы Кавказа и Закавказья', 'Категория:Трансконтинентальные государства']
#
# ...

# %%
def cat_tree(lst):
    for l in lst:
        print(l)
        try:
            print(wikipedia.categorytree(l))

        except:
            print("No such page")
        
        print('')
            
cat_tree(p.categories)
print('')
print('')
print('')
cat_tree(s.categories)
#wikipedia.categorytree("Авторы-исполнители Санкт-Петербурга")
# Out:
# Категория:Аудиостатьи
# {'Категория:Аудиостатьи': {'depth': 0, 'sub-categories': {}, 'links': [], 'parent-categories': ['Категория:Википедия:Статьи, объединённые по внутренним признакам']}}
#
# Категория:Баренц-регион
# No such page
#
# Категория:Государства «Большой двадцатки»
# {'Категория:Государства «Большой двадцатки»': {'depth': 0, 'sub-categories': {}, 'links': [], 'parent-categories': ['Категория:Большая двадцатка']}}
#
# Категория:Государства по алфавиту
# {'Категория:Государства по алфавиту': {'depth': 0, 'sub-categories': {}, 'links': [], 'parent-categories': ['Категория:Категории географических объектов', 'Категория:Метакатегории']}}
#
# Категория:Государства постсоветского пространства
# ...

# %%
import mediawiki
wikipedia = mediawiki.MediaWiki(lang=u'ru')
wikipedia.page(pageid=72)
# Out:
# <MediaWikiPage 'Преголя'>
